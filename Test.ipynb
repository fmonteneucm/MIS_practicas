# %%
import astropy
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
# Creamos un vector x
x = np.arange(1,20)

# Creamos un vector y con pendiente 1.5, pero con un cierto ruido
ynoise = 0.2*np.random.randn(len(x))
y = 1.5*x + 4+ynoise

# %%
# Esto es necesario porque la función de ajuste espera vectores columna
x = x.reshape(-1,1)
y = y.reshape(-1,1)

# %%
# Creamos el objeto que realiza la regresión lineal
linear_regressor = LinearRegression()

# Hacemos el ajuste con los datos x e y 
linear_regressor.fit(x,y)

# Generamos la predicción que el modelo ajustado nos da para x: y_model. Este modelo se evalua en los valores de x
y_model = linear_regressor.predict(x)

# Obtenemos la pendiente
pendiente = linear_regressor.coef_[0][0]

# %%
# Representamos el resultado y escribimos la pendiente como título del gráfico

plt.figure(figsize=(10,8))
plt.scatter(x,y,marker='+',color='red')
plt.plot(x,y_model,ls='-',color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'Pendiente = {pendiente:5.2f}')
# Out:
# Text(0.5, 1.0, 'Pendiente =  1.51')

# %%
# Otra forma de hacerlo con el paquete numpy.polyfit

# Creamos un vector x
x = np.arange(1,20)

# Creamos un vector y con pendiente 1.5, pero con un cierto ruido
ynoise = 0.2*np.random.randn(len(x))
y = 1.5*x + 4+ynoise

coeffs = np.polyfit(x, y, 1)

# Pendiente
m = coeffs[0]
n = coeffs[1]
y_model = m*x+n

# %%
#Representamos el resultado y escribimos la pendiente como título del gráfico

plt.figure(figsize=(10,8))
plt.scatter(x,y,marker='+',color='red')
plt.plot(x,y_model,ls='-',color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'Pendiente = {m:5.2f}')
# Out:
# Text(0.5, 1.0, 'Pendiente =  1.50')
